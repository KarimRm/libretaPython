# %% [markdown]
# <a href="https://colab.research.google.com/github/KarimRm/libretaPython/blob/main/Analizando_Datos_Pandas_Nacimientos_MX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Descarga los datos directamente con pandas, muestra el tipo de datos más importantes
csv_url = "/content/data/Nacimientos_2023.csv"

df_nacimientos = pd.read_csv(csv_url, engine='python')

df_nacimientos
# Out:
#          NACIOEXTRANJERO  ENTIDADNACIMIENTO  MUNICIPIONACIMIENTO  EDAD  \
# 0                      2                  9                   12    25
# 1                      2                 15                   33    22
# 2                      2                 12                   28    20
# 3                      2                 13                   63    28
# 4                      2                 15                  101    29
# ...                  ...                ...                  ...   ...
# 1521275                2                  9                   15    23
# 1521276                2                 15                   40    16
# 1521277                2                  8                   19    21
# 1521278                2                 14                  114    36
# 1521279                2                 11                   30    40
#
#          SECONSIDERAINDIGENA  HABLALENGUAINDIGENA FECHANACIMIENTOMADRE  \
# ...

# %%
#Indice con las fechas, usando una transformación a tipo timestamp.
df_nacimientos['FECHANACIMIENTO'] = pd.to_datetime(df_nacimientos['FECHANACIMIENTO'], format='%d/%m/%Y')

df_nacimientos_by_fecha = df_nacimientos.set_index('FECHANACIMIENTO')

df_nacimientos_by_fecha
# Out:
#                  NACIOEXTRANJERO  ENTIDADNACIMIENTO  MUNICIPIONACIMIENTO  \
# FECHANACIMIENTO
# 2023-05-09                     2                  9                   12
# 2023-02-28                     2                 15                   33
# 2023-06-17                     2                 12                   28
# 2023-11-21                     2                 13                   63
# 2023-05-08                     2                 15                  101
# ...                          ...                ...                  ...
# 2023-11-18                     2                  9                   15
# 2023-08-14                     2                 15                   40
# 2023-11-26                     2                  8                   19
# 2023-11-18                     2                 14                  114
# 2023-09-30                     2                 11                   30
#
#                  EDAD  SECONSIDERAINDIGENA  HABLALENGUAINDIGENA  \
# ...

# %%
df_nacimientos_by_fecha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1521280 entries, 2023-05-09 to 2023-09-30
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   NACIOEXTRANJERO             1521280 non-null  int64
#  1   ENTIDADNACIMIENTO           1521280 non-null  int64
#  2   MUNICIPIONACIMIENTO         1521280 non-null  int64
#  3   EDAD                        1521280 non-null  int64
#  4   SECONSIDERAINDIGENA         1521280 non-null  int64
#  5   HABLALENGUAINDIGENA         1521280 non-null  int64
#  6   FECHANACIMIENTOMADRE        1521280 non-null  object
#  7   ESTADOCONYUGAL              1521280 non-null  int64
#  8   RESIDEEXTRANJERO            1521280 non-null  int64
#  9   ENTIDADRESIDENCIA           1521280 non-null  int64
#  10  MUNICIPIORESIDENCIA         1521280 non-null  int64
#  11  LOCALIDADRESIDENCIA         1521280 non-null  int64
# ...

# %%
#Filtra los datos para un solo año y para un estado solamente, en este caso Sonora(su numero de entidad es 26)

df_nacimientos_byYear = df_nacimientos_by_fecha.loc['2023-01-01':'2023-01-31']
df_nacimientos_byYear_byState = df_nacimientos_byYear.loc[df_nacimientos_byYear['ENTIDADNACIMIENTO'] == 26]
df_nacimientos_byYear_byState
# Out:
#                  NACIOEXTRANJERO  ENTIDADNACIMIENTO  MUNICIPIONACIMIENTO  \
# FECHANACIMIENTO
# 2023-01-04                     2                 26                   66
# 2023-01-23                     2                 26                  999
# 2023-01-11                     2                 26                   30
# 2023-01-21                     2                 26                   42
# 2023-01-11                     2                 26                    2
# ...                          ...                ...                  ...
# 2023-01-09                     2                 26                   39
# 2023-01-12                     2                 26                   18
# 2023-01-16                     2                 26                   18
# 2023-01-15                     2                 26                    2
# 2023-01-14                     2                 26                   18
#
#                  EDAD  SECONSIDERAINDIGENA  HABLALENGUAINDIGENA  \
# ...

# %%
#imprimir la columna sexo
df_nacimientos_byYear_byState['SEXO']
# Out:
# FECHANACIMIENTO
# 2023-01-04    1
# 2023-01-23    2
# 2023-01-11    2
# 2023-01-21    1
# 2023-01-11    1
#              ..
# 2023-01-09    2
# 2023-01-12    2
# 2023-01-16    1
# 2023-01-15    1
# 2023-01-14    1
# Name: SEXO, Length: 2712, dtype: int64

# %%
#Modifica los valores de variables cualitativas para que sean más representativas en su análisis

df_nacimientos_byYear_byState['SEXO'] = df_nacimientos_byYear_byState['SEXO'].replace({1 : 'Masculino', 2: 'Femenino'})

df_nacimientos_byYear_byState['SEXO']
# Out:
# <ipython-input-18-a54438cce0e8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nacimientos_byYear_byState['SEXO'] = df_nacimientos_byYear_byState['SEXO'].replace({1 : 'Masculino', 2: 'Femenino'})
# FECHANACIMIENTO
# 2023-01-04    Masculino
# 2023-01-23     Femenino
# 2023-01-11     Femenino
# 2023-01-21    Masculino
# 2023-01-11    Masculino
#                 ...
# 2023-01-09     Femenino
# 2023-01-12     Femenino
# 2023-01-16    Masculino
# 2023-01-15    Masculino
# 2023-01-14    Masculino
# Name: SEXO, Length: 2712, dtype: object

# %%
#Realiza un análisis exploratorio básico usando pandas, haciendo algunas gráficas que muestren algunos detalles importantes o interesantes y con algunas regrupaciones simples o complejas.

df_MyH = df_nacimientos_byYear_byState.filter(like='SEXO').value_counts()

df_MyH.plot(kind='pie').set_title('Porcentaje de nacimientos por sexo año 2023')
# Out:
# Text(0.5, 1.0, 'Porcentaje de nacimientos por sexo año 2023')

# %%
#Cambiamos los valores de la columna 'SECONSIDERAINDIGENA' a tipo texto para poder presentar mejor los datos
df_nacimientos_byYear_byState['SECONSIDERAINDIGENA'] = df_nacimientos_byYear_byState['SECONSIDERAINDIGENA'].replace({1 : 'Si', 2: 'No'})
# Out:
# <ipython-input-35-18a6f79f6d89>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nacimientos_byYear_byState['SECONSIDERAINDIGENA'] = df_nacimientos_byYear_byState['SECONSIDERAINDIGENA'].replace({1 : 'Si', 2: 'No'})

# %%
df_nacimientos_ind = df_nacimientos_byYear_byState[['EDAD','MUNICIPIONACIMIENTO']]
df_nacimientos_ind
# Out:
#                  EDAD  MUNICIPIONACIMIENTO
# FECHANACIMIENTO
# 2023-01-04         33                   66
# 2023-01-23         31                  999
# 2023-01-11         34                   30
# 2023-01-21         25                   42
# 2023-01-11         25                    2
# ...               ...                  ...
# 2023-01-09         18                   39
# 2023-01-12         29                   18
# 2023-01-16         34                   18
# 2023-01-15         22                    2
# 2023-01-14         27                   18
#
# [2712 rows x 2 columns]

# %%
df_municipal = df_nacimientos_ind.loc[df_nacimientos_ind['MUNICIPIONACIMIENTO'] <= 72]
df_municipal.plot(x='MUNICIPIONACIMIENTO', y='EDAD', kind='scatter').set_title('Nacimientos por edad y municipio')
# Out:
# Text(0.5, 1.0, 'Nacimientos por edad y municipio')

# %%
##Reflexion
#Tiene que hacerse resaltar que los datos que se estan utilizando sufren de datos erroneos, por ejemplo fue necesario filtrar los municipios (registrados con su numero de entidad), sin embargo existen celdas con numeros
#mayores a 72, el cual es el ultimo numero de entidades de los municipios en sonora

#Si investigamos sobre el numero que le corresponde a cada municipio podemos ver que hay mas nacimientos como en municipios como Hermosillo(30), San Luis Rio Colorado(55), Nogales(43) que en otros como Bacanora(9), Baviácora(14), Trincheras(64)
#Lo cual se podria considerar obvio, pero nos da una manera de representar la densidad de las poblaciones futuras, ya que solo estamos hablando de nacimientos.
